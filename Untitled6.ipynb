# %% [markdown]
# <a href="https://colab.research.google.com/github/mwalaa455-tech/Session-1-task/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Book:
  def __init__(self,title, author, isbn, available ):
     self.title = title
     self.author = author
     self.isbn = isbn
     self.available = available
display_info = Book("freedom", "walaa", 11, True)
print(display_info.title, display_info.author, display_info.isbn, display_info.available)
# Out:
# freedom walaa 11 True
