# %% [markdown]
# <a href="https://colab.research.google.com/github/mwalaa455-tech/Session-1-task/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Tem = 22
if Tem >= 30:
  print("It's a hot day. Stay hydrated!")
elif Tem >= 20 and Tem <= 29:
  print("It's a warm day. Enjoy the weather!")
elif Tem >= 10 or Tem <= 19:
  print("It's a cool day. Wear a jacket!")
else:
  print("It's a cold day. Stay warm!")
# Out:
# It's a warm day. Enjoy the weather!
