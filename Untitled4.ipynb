# %% [markdown]
# <a href="https://colab.research.google.com/github/mwalaa455-tech/Session-1-task/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# task 1
contacts = {
    'walaa':'02354',
    'mo':'02333',
    'katy':'02344'
}
print(contacts.keys())

if 'walaa' in contacts :
  print(contacts['walaa'])
if 'mo' in contacts:
  print(contacts['mo'])
if 'katy' in contacts:
  print(contacts['katy'])
# Out:
# dict_keys(['walaa', 'mo', 'katy'])
# 02354
# 02333
# 02344

# %%
# test 2
student = {
    'name':'walaa',
    'grade':{'sub1':50, 'sub2':60, 'sub3':70}
}
